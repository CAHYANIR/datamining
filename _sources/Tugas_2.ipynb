# %% [markdown]
# # Tugas 2

# %% [markdown]
# # Entropy
# $$-\Sigma_i^n p_i log_2 p_i$$
#
# # Equal width binning
# $$ v_i= x_{min} + iw $$

# %%
import pandas as pd

# %%
# %cd /content/drive/MyDrive/datamining/tugas
# Out:
# /content/drive/MyDrive/datamining/tugas
